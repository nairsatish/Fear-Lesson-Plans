# %% [markdown]
# <a href="https://colab.research.google.com/github/KhuramC/Fear-Lesson-Plans/blob/master/D1/Fear_Breadboard_Circuit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fear Circuit Simulation
# As mentioned earlier, the neural pathways for both fear and reward can be thought of as circuits. Here you will design a very simplified circuit to try and emulate it using the Univ of Colorado-Boulder circuit construction site given
#  [**here**](https://phet.colorado.edu/en/simulations/circuit-construction-kit-dc) and clicking the play button to start.

# %% [markdown]
# # INSERT PICTURE HERE OF FULL NEURAL PATHWAY
#
# ---
#  CHALLENGE: Go into the lab and try to build the tone and shock pathways together as a circuit. The synapses should be represent as resistors, while the tone and shock are represented as batteries. The amygdala is represented as the light bulb. How much it shines determines whether it is in a fear state or not. Make sure the **shock pathway is stronger than the tone pathway.** A sample solution is available at the end of the notebook.
#
# *  There should be two batteries, one for tone and shock their own path and meet up right before the light bulb(representing the amygdala).
# *  Each pathway should have 3 total resistors(the sensory neuron, the thalamic neuron, and then the one on the amygdala)
# *  **The synapses for the sensory neuron and thalamic neuron should stay at the standard value.**
# * Because this is a circuit, one needs to make sure to connect it back up to the ends of batteries to complete the circuit.
# * Resistance works inversly. A lower resistance will yield a brighter bulb.
# * To test one pathway alone, turn the other battery's voltage to 0(this is like sending no shock or no tone).
# * An example of the tone pathway alone is given here.

# %% [markdown]
# # Tone Pathway as a Circuit
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Questions:
#
#
# 1.   Why are the synapses represented as resistors?
# 2.   Why are the tone and shock represented as batteries?
# 3.   Which synapse has the higher resistance(i.e the lower strength): the tone pathway or the shock pathway?

# %% [markdown]
# # Extras: Building a More Advanced Fear Circuit
# The amygdala fires, and it would make more sense for this to be represented as the light bulb flashing x times in a second. Here we will be adapting the flashing LED experiment given [**here**](https://elonics.org/adjustable-led-flasher-using-555-timer/) to do just that. The video below gives a nice tutorial. However there are some differences:
# First, the R1 and R2 resistor values are not quite the same, although they are still in the same location. The only addition is the variable resistor, shown as R5 in the circuit. This will allow you to change the resistance how you want, representing change the strength of the synapse.

# %% [markdown]
# # Circuit We Will be Creating
# ![image.png](data:image/png;base64,...)

# %%
#@title Run cell to load building tutorial

from IPython.display import YouTubeVideo
YouTubeVideo('TTQnhIkw4Bk')

# %% [markdown]
# # Example Completed Breadboard
# PUT PICTURE OF COMPLETED BREADBOARD HERE

# %% [markdown]
# #Solution: Tone(Top) and Shock(Bottom) Pathway as a Circuit
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Conclusion
# You should now better understand how the neural pathways work and how they are like circuits.
